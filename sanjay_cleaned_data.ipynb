# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys() :
  print('user uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d22f3ad7-6422-43ab-90b9-a3031f54375d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d22f3ad7-6422-43ab-90b9-a3031f54375d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')

# %%
df.head()
# Out:
# ...
#    OBJECTID_1  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# 0           1      Alaska           2    Pacific         AK            2
# 1           2  California           6    Pacific         CA            6
# 2           3      Hawaii          15    Pacific         HI           15
# 3           4       Idaho          16   Mountain         ID           16
# 4           5      Nevada          32   Mountain         NV           32
#
#              State  AllAge_B_AA_Rate  AllAge_B_Lower_CI  AllAge_B_Upper_CI  \
# 0     Alaska(6,10)             56.04              53.22              58.97
# 1  California(7,8)             42.06              41.77              42.35
# 2      Hawaii(7,8)             45.69              44.27              47.16
# 3       Idaho(7,8)             50.34              48.87              51.85
# 4     Nevada(6,10)             55.20              54.01              56.40
#
#    ...  Age65over_F_AA_Rate Age65over_F_Lower_CI  Age65over_F_Upper_CI  \
# ...

# %%
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
df.drop(['STATE_FIPSN'], axis = 1)
# Out:
# ...
#     OBJECTID_1            STATE_NAME  STATE_FIPS          SUB_REGION  \
# 0            1                Alaska           2             Pacific
# 1            2            California           6             Pacific
# 2            3                Hawaii          15             Pacific
# 3            4                 Idaho          16            Mountain
# 4            5                Nevada          32            Mountain
# 5            6                Oregon          41             Pacific
# 6            7            Washington          53             Pacific
# 7            8               Arizona           4            Mountain
# 8            9              Arkansas           5  West South Central
# 9           10              Colorado           8            Mountain
# 10          11                  Iowa          19  West North Central
# 11          12                Kansas          20  West North Central
# 12          13             Louisiana          22  West South Central
# ...

# %%
import pandas as pd
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
df['AllAge_B_AA_Rate'] = df['AllAge_B_AA_Rate'].astype(int)
df.head()
# Out:
# ...
#    OBJECTID_1  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# 0           1      Alaska           2    Pacific         AK            2
# 1           2  California           6    Pacific         CA            6
# 2           3      Hawaii          15    Pacific         HI           15
# 3           4       Idaho          16   Mountain         ID           16
# 4           5      Nevada          32   Mountain         NV           32
#
#              State  AllAge_B_AA_Rate  AllAge_B_Lower_CI  AllAge_B_Upper_CI  \
# 0     Alaska(6,10)                56              53.22              58.97
# 1  California(7,8)                42              41.77              42.35
# 2      Hawaii(7,8)                45              44.27              47.16
# 3       Idaho(7,8)                50              48.87              51.85
# 4     Nevada(6,10)                55              54.01              56.40
#
#    ...  Age65over_F_AA_Rate Age65over_F_Lower_CI  Age65over_F_Upper_CI  \
# ...

# %%
import pandas as pd
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
df = df.rename(columns={'OBJECTID_1': 'ID'})
df.head()
# Out:
# ...
#    ID  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# 0   1      Alaska           2    Pacific         AK            2
# 1   2  California           6    Pacific         CA            6
# 2   3      Hawaii          15    Pacific         HI           15
# 3   4       Idaho          16   Mountain         ID           16
# 4   5      Nevada          32   Mountain         NV           32
#
#              State  AllAge_B_AA_Rate  AllAge_B_Lower_CI  AllAge_B_Upper_CI  \
# 0     Alaska(6,10)             56.04              53.22              58.97
# 1  California(7,8)             42.06              41.77              42.35
# 2      Hawaii(7,8)             45.69              44.27              47.16
# 3       Idaho(7,8)             50.34              48.87              51.85
# 4     Nevada(6,10)             55.20              54.01              56.40
#
#    ...  Age65over_F_AA_Rate Age65over_F_Lower_CI  Age65over_F_Upper_CI  \
# ...

# %%
import pandas as pd
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
df['Total_Rate'] = df['AllAge_B_AA_Rate'] + df['AllAge_M_AA_Rate']
df.head()
# Out:
# ...
#    OBJECTID_1  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# 0           1      Alaska           2    Pacific         AK            2
# 1           2  California           6    Pacific         CA            6
# 2           3      Hawaii          15    Pacific         HI           15
# 3           4       Idaho          16   Mountain         ID           16
# 4           5      Nevada          32   Mountain         NV           32
#
#              State  AllAge_B_AA_Rate  AllAge_B_Lower_CI  AllAge_B_Upper_CI  \
# 0     Alaska(6,10)             56.04              53.22              58.97
# 1  California(7,8)             42.06              41.77              42.35
# 2      Hawaii(7,8)             45.69              44.27              47.16
# 3       Idaho(7,8)             50.34              48.87              51.85
# 4     Nevada(6,10)             55.20              54.01              56.40
#
# ...

# %%
import pandas as pd
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
df = df.drop_duplicates()
df.head()
# Out:
# ...
#    OBJECTID_1  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# 0           1      Alaska           2    Pacific         AK            2
# 1           2  California           6    Pacific         CA            6
# 2           3      Hawaii          15    Pacific         HI           15
# 3           4       Idaho          16   Mountain         ID           16
# 4           5      Nevada          32   Mountain         NV           32
#
#              State  AllAge_B_AA_Rate  AllAge_B_Lower_CI  AllAge_B_Upper_CI  \
# 0     Alaska(6,10)             56.04              53.22              58.97
# 1  California(7,8)             42.06              41.77              42.35
# 2      Hawaii(7,8)             45.69              44.27              47.16
# 3       Idaho(7,8)             50.34              48.87              51.85
# 4     Nevada(6,10)             55.20              54.01              56.40
#
#    ...  Age65over_F_AA_Rate Age65over_F_Lower_CI  Age65over_F_Upper_CI  \
# ...

# %%
data = [56.04, 42.06, 45.69, 50.34, 55.2, 54.68, 55.83, 48.09, 78.14, 42.52, 63.05, 59.85, 67.49, 55.97, 72.89, 54.83, 57.71, 39.57, 57.26, 69.16, 58.95, 51.93, 26.86, 44.09, 66.41, 59.81, 69.46, 49.63, 58.98, 64.05, 64.67, 72.89, 92.24, 73.68, 56.43, 61.81, 64.03, 75.53, 64.33, 56.14, 58.87, 68.76, 68.51, 64.01, 70.57, 65.49, 75.14, 62.36, 58.56, 79.34, 59.75]
import pandas as pd
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
print(Q1,Q3)
# Out:
# 55.515 68.0

# %%
IQR_value =(Q3-Q1)
print(IQR_value)
# Out:
# 12.485

# %%
import pandas as pd
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
lower_bound_value = 45
upper_bound_value = 75

df['AllAge_B_AA_Rate'] = df['AllAge_B_AA_Rate'].clip(lower=lower_bound_value, upper=upper_bound_value)
df.head()
# Out:
# ...
#    OBJECTID_1  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# 0           1      Alaska           2    Pacific         AK            2
# 1           2  California           6    Pacific         CA            6
# 2           3      Hawaii          15    Pacific         HI           15
# 3           4       Idaho          16   Mountain         ID           16
# 4           5      Nevada          32   Mountain         NV           32
#
#              State  AllAge_B_AA_Rate  AllAge_B_Lower_CI  AllAge_B_Upper_CI  \
# 0     Alaska(6,10)             56.04              53.22              58.97
# 1  California(7,8)             45.00              41.77              42.35
# 2      Hawaii(7,8)             45.69              44.27              47.16
# 3       Idaho(7,8)             50.34              48.87              51.85
# 4     Nevada(6,10)             55.20              54.01              56.40
#
#    ...  Age65over_F_AA_Rate Age65over_F_Lower_CI  Age65over_F_Upper_CI  \
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
missing_values = df.isnull().sum()
infinite_values = df.isin([np.inf, -np.inf]).sum()
print(missing_values)
print(infinite_values)
# Out:
# OBJECTID_1                      0
# STATE_NAME                      0
# STATE_FIPS                      0
# SUB_REGION                      0
# STATE_ABBR                      0
#                                ..
# Age65over_F_Recent_5yr_Trend    0
# Age65over_F_Lower_Trend_CI      0
# Age65over_F_Upper_Trend_CI      0
# Shape__Area                     0
# Shape__Length                   0
# Length: 129, dtype: int64
# OBJECTID_1                      0
# STATE_NAME                      0
# STATE_FIPS                      0
# SUB_REGION                      0
# STATE_ABBR                      0
#                                ..
# Age65over_F_Recent_5yr_Trend    0
# Age65over_F_Lower_Trend_CI      0
# Age65over_F_Upper_Trend_CI      0
# Shape__Area                     0
# Shape__Length                   0
# Length: 129, dtype: int64
# ...
#    OBJECTID_1  STATE_NAME  STATE_FIPS SUB_REGION STATE_ABBR  STATE_FIPSN  \
# ...

# %%
import pandas as pd

data = { 'State': [ 'Alaska(6,10)', 'California(7,8)', 'Hawaii(7,8)', 'Idaho(7,8)', 'Nevada(6,10)',
        'Oregon(6,10)', 'Washington(5,10)', 'Arizona(6,10)', 'Arkansas(6,10)', 'Colorado(6,10)',
        'Iowa(7,8)', 'Kansas(6,10)', 'Louisiana(7,8)', 'Minnesota(6,10)', 'Missouri(6,10)',
        'Montana(6,10)', 'Nebraska(6,10)', 'New Mexico(7,8)', 'North Dakota(6,10)', 'Oklahoma(6,10)',
        'South Dakota(6,10)', 'Texas(6,10)', 'Utah(7,8)', 'Wyoming(6,10)', 'Alabama(6,10)',
        'Connecticut(7,8)', 'Delaware(6,10)', 'District of Columbia(6,10)', 'Florida(6,10)',
        'Georgia(7,8)', 'Illinois(6,10)', 'Indiana(6,10)', 'Kentucky(7,8)', 'Maine(6,10)',
        'Maryland(6,10)', 'Massachusetts(7,8)', 'Michigan(5,10)', 'Mississippi(6,10)', 'New Hampshire(6,10)',
        'New Jersey(7,8)', 'New York(7,8)', 'North Carolina(6,10)', 'Ohio(6,10)', 'Pennsylvania(6,10)',
        'Rhode Island(6,10)', 'South Carolina(6,10)', 'Tennessee(6,10)', 'Vermont(6,10)', 'Virginia(6,10)',
        'West Virginia(6,10)', 'Wisconsin(6,10)', ]}
df = pd.DataFrame(data)
df[['STATE_X', 'STATE_Y']] = df['State'].str.extract(r'\((\d+),(\d+)\)')
df.drop('State', axis=1, inplace=True)
df.head()
# Out:
#   STATE_X STATE_Y
# 0       6      10
# 1       7       8
# 2       7       8
# 3       7       8
# 4       6      10

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('NCI_State_Lung_Cancer_Incidence_Rates.csv')
df = df.drop(['STATE_FIPSN'], axis=1)
df['AllAge_B_AA_Rate'] = df['AllAge_B_AA_Rate'].astype(int)
df = df.rename(columns={'OBJECTID_1': 'ID'})
df['Total_Rate'] = df['AllAge_B_AA_Rate'] + df['AllAge_M_AA_Rate']
df = df.drop_duplicates()
lower_bound_value = 45
upper_bound_value = 75
df['AllAge_B_AA_Rate'] = df['AllAge_B_AA_Rate'].clip(lower=lower_bound_value, upper=upper_bound_value)
data = {'State': [ 'Alaska(6,10)', 'California(7,8)', 'Hawaii(7,8)', 'Idaho(7,8)', 'Nevada(6,10)',
        'Oregon(6,10)', 'Washington(5,10)', 'Arizona(6,10)', 'Arkansas(6,10)', 'Colorado(6,10)',
        'Iowa(7,8)', 'Kansas(6,10)', 'Louisiana(7,8)', 'Minnesota(6,10)', 'Missouri(6,10)',
        'Montana(6,10)', 'Nebraska(6,10)', 'New Mexico(7,8)', 'North Dakota(6,10)', 'Oklahoma(6,10)',
        'South Dakota(6,10)', 'Texas(6,10)', 'Utah(7,8)', 'Wyoming(6,10)', 'Alabama(6,10)',
        'Connecticut(7,8)', 'Delaware(6,10)', 'District of Columbia(6,10)', 'Florida(6,10)',
        'Georgia(7,8)', 'Illinois(6,10)', 'Indiana(6,10)', 'Kentucky(7,8)', 'Maine(6,10)',
        'Maryland(6,10)', 'Massachusetts(7,8)', 'Michigan(5,10)', 'Mississippi(6,10)', 'New Hampshire(6,10)',
        'New Jersey(7,8)', 'New York(7,8)', 'North Carolina(6,10)', 'Ohio(6,10)', 'Pennsylvania(6,10)',
        'Rhode Island(6,10)', 'South Carolina(6,10)', 'Tennessee(6,10)', 'Vermont(6,10)', 'Virginia(6,10)',
        'West Virginia(6,10)', 'Wisconsin(6,10)',]}
df_split = pd.DataFrame(data)
df_split[['STATE_X', 'STATE_Y']] = df_split['State'].str.extract(r'\((\d+),(\d+)\)')
df_split.drop('State', axis=1, inplace=True)
combined_df = pd.concat([df, df_split], axis=1)
print(combined_df)
df.head()
combined_df.to_csv('combined_data.csv', index=False)
# Out:
#     ID            STATE_NAME  STATE_FIPS          SUB_REGION STATE_ABBR  \
# 0    1                Alaska           2             Pacific         AK
# 1    2            California           6             Pacific         CA
# 2    3                Hawaii          15             Pacific         HI
# 3    4                 Idaho          16            Mountain         ID
# 4    5                Nevada          32            Mountain         NV
# 5    6                Oregon          41             Pacific         OR
# 6    7            Washington          53             Pacific         WA
# 7    8               Arizona           4            Mountain         AZ
# 8    9              Arkansas           5  West South Central         AR
# 9   10              Colorado           8            Mountain         CO
# 10  11                  Iowa          19  West North Central         IA
# 11  12                Kansas          20  West North Central         KS
# ...

# %%
# Save the combined DataFrame to a CSV file
combined_df.to_csv('modified_data.csv', index=False)
